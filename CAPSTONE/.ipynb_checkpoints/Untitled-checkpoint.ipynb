# %%
import pandas as pd

df = pd.read_csv("TRANSPORT.csv")
print(df)
# Out:
#   Bus_ID Route Departure_Time  Delay_Minutes
# 0     B1    A1          08:00             10
# 1     B2    A2          09:00              0
# 2     B3    A1          10:00             15
# 3     B4    A3          11:00              5
# 4     B5    A2          12:00             20
# 5     B6    A3          13:00              8
# 6     B7    A1          14:00             12
# 7     B8    A2          15:00              3
# 8     B9    A3          16:00             25
# 9    B10    A1          17:00              7

# %%
df.groupby("Route")["Delay_Minutes"].mean()
# Out:
# Route
# A1    11.000000
# A2     7.666667
# A3    12.666667
# Name: Delay_Minutes, dtype: float64

# %%
df["Delay_Minutes"].sum()
# Out:
# np.int64(105)

# %%
df["Delay_Minutes"].max()
# Out:
# 25

# %%
df.groupby("Route")["Delay_Minutes"].mean().sort_values(ascending=False)
# Out:
# Route
# A3    12.666667
# A1    11.000000
# A2     7.666667
# Name: Delay_Minutes, dtype: float64
