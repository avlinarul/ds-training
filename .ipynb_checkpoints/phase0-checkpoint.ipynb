# %%
print("Hello — my data science journey starts here!")
# Out:
# Hello — my data science journey starts here!

# %%
print("helloo !!!!!!!!!!!!!!!")
# Out:
# helloo !!!!!!!!!!!!!!!

# %%
print("my journey starts here!")
# Out:
# my journey starts here!

# %%
stickers = 100
students = 7

each_student_gets = stickers // students
left_over = stickers % students

print(each_student_gets)
print(left_over)
# Out:
# 14
# 2

# %%
customer = "Ravi"
bill = 160
 
print(f"Welcome {customer}! Your bill is ₹{bill}.")
 
print(customer.upper())   
print(len(customer))
# Out:
# Welcome Ravi! Your bill is ₹160.
# RAVI
# 4

# %%
bill = 560
free_delivery = bill > 500
print(free_delivery)        
 
is_empty = bill == 0
print(is_empty)
# Out:
# True
# False

# %%
bill = 560
free_delivery = bill > 500
print(free_delivery)

is_empty = bill == 0
print(is_empty)
# Out:
# True
# False

# %%
fruits = ["apple", "orange", "banana", "mango"]

print(fruits[0])
print(fruits[-1])

fruits.append("grape")
print(len(fruits))

daily_sales = [1200, 980, 1500, 1100, 1750]

print(sum(daily_sales))
print(max(daily_sales))
# Out:
# apple
# mango
# 5
# 6530
# 1750

# %%
prices = {"apple": 30, "orange": 20, "banana": 10}

print(prices["apple"])

prices["mango"] = 40

print(prices)
# Out:
# 30
# {'apple': 30, 'orange': 20, 'banana': 10, 'mango': 40}

# %%
quantity = 12

if quantity >= 10:
    discount = 0.10
elif quantity >= 5:
    discount = 0.05
else:
    discount = 0

print(discount)
# Out:
# 0.1

# %%
quantity = 7

if quantity >= 10:
    discount = 0.10
elif quantity >= 5:
    discount = 0.05
else:
    discount = 0

print(discount)
# Out:
# 0.05

# %%
quantity = 3

if quantity >= 10:
    discount = 0.10
elif quantity >= 5:
    discount = 0.05
else:
    discount = 0

print(discount)
# Out:
# 0

# %%
basket = ["apple", "apple", "orange", "banana"]
prices = {"apple": 30, "orange": 20, "banana": 10}

total = 0

for fruit in basket:
    total = total + prices[fruit]

print(total)
# Out:
# 90

# %%
basket = ["apple", "apple", "orange", "banana"]
prices = {"apple": 100, "orange": 20, "banana": 10}

total = 0

for fruit in basket:
    total = total + prices[fruit]

print(total)
# Out:
# 230

# %%
def bill_with_tax(amount):
    tax = amount * 0.05
    return amount + tax

print(bill_with_tax(1000))
print(bill_with_tax(250))

def make_receipt(customer, amount):
    return f"{customer} paid ₹{amount}. Thank you!"

print(make_receipt("Ravi", 560))
# Out:
# 1050.0
# 262.5
# Ravi paid ₹560. Thank you!

# %%
def bill_with_tax(amount):
    tax = amount * 0.05
    return amount + tax

print(bill_with_tax(789))
print(bill_with_tax(250))

def make_receipt(customer, amount):
    return f"{customer} paid ₹{amount}. Thank you!"

print(make_receipt("Ravi", 560))
# Out:
# 828.45
# 262.5
# Ravi paid ₹560. Thank you!

# %%
import pandas as pd

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
import pandas as pd

sales = pd.read_csv("sales.csv")
print(sales)
# Out:
#   Product  Quantity  Price
# 0   Apple        10     30
# 1  Orange         5     20
# 2  Banana         8     10
# 3   Mango        12     40

# %%
import pandas as pd

sales = pd.read_csv("sales.csv")
print(sales.head)
# Out:
# <bound method NDFrame.head of   Product  Quantity  Price
# 0   Apple        10     30
# 1  Orange         5     20
# 2  Banana         8     10
# 3   Mango        12     40>

# %%
import pandas as pd

sales = pd.read_csv("sales.csv")
print(sales.head())
# Out:
#   Product  Quantity  Price
# 0   Apple        10     30
# 1  Orange         5     20
# 2  Banana         8     10
# 3   Mango        12     40

# %%
apple = 10
print(appleee)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 apple = 10
# ----> 2 print(appleee)
#
# NameError: name 'appleee' is not defined

# %%
apple = 10
print(apple)
# Out:
# 10

# %%
marks=99

if(marks>90):
    print("pass")
elseif:
    print("fail")
# Out:
#   Cell In[30], line 5
#     elseif:
#            ^
# SyntaxError: invalid syntax

# %%
marks=99

if(marks>90):
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
#part E
name = "Apple"
price = 30
quantity = 5

print(f"{name}: {quantity} x ₹{price} = ₹{price * quantity}")
# Out:
# Apple: 5 x ₹30 = ₹150

# %%
sales = [1200, 980, 1500, 1100, 1750]
print("Total:", sum(sales))
print("Largest:", max(sales))
# Out:
# Total: 6530
# Largest: 1750

# %%
quantity = 12
if quantity >= 10:
    print("10% discount")
elif quantity >= 5:
    print("5% discount")
else:
    print("No discount")
# Out:
# 10% discount

# %%
basket = ["apple", "apple", "orange", "banana"]
prices = {
    "apple": 30,
    "orange": 20,
    "banana": 10
}
total = 0
for item in basket:
    total += prices[item]

print("Total cost:", total)
# Out:
# Total cost: 90

# %%
def add_tax(price):
    return price * 1.05

print(add_tax(1000))
# Out:
# 1050.0

# %%
#List: Stores multiple items in order and accesses them using an index.
#Dictionary: Stores data as key-value pairs and accesses values using a key.
fruits = ["apple", "banana", "mango"]      # List

prices = {"apple": 30, "banana": 10}  #dict
