# %%
print("Hello — my data science journey starts here!")
# Out:
# Hello — my data science journey starts here!

# %%
print("helloo !!!!!!!!!!!!!!!")
# Out:
# helloo !!!!!!!!!!!!!!!

# %%
print("This is Avlin!!!")
# Out:
# This is Avlin!!!
